# %%
import pandas as pd
import numpy as np
from src.clean_data import clean_data

# %%
df=pd.read_json('data/data.json')

# %%
df_clean=clean_data(df)

# %%
df_clean.head()
# Out:
#    fraud  delivery_method  fb_published  ticket_type_length  \
# 0   True              0.0             0               False
# 1  False              1.0             0               False
# 2  False              1.0             0               False
# 3  False              1.0             0               False
# 4  False              0.0             1               False
#
#    gross_profits_dummie  channels  user_type  sale_duration2
# 0                     0         5          1              33
# 1                     3         0          3              28
# 2                     4         8          3              54
# 3                     3         6          3               0
# 4                     4        11          3              63

# %%
df_clean.to_csv('data/clean_data.csv')

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading https://files.pythonhosted.org/packages/37/db/c332a994798107247e5d361f1958e505c1c0831f81d05f79672f7740c54c/xgboost-1.1.0-py3-none-macosx_10_13_x86_64.macosx_10_14_x86_64.macosx_10_15_x86_64.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 2.6MB/s eta 0:00:01
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.7/site-packages (from xgboost) (1.17.4)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.7/site-packages (from xgboost) (1.3.1)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.1.0

# %%
# !brew install libomp
# Out:
# Updating Homebrew...
# ==> Auto-updated Homebrew!
# Updated 1 tap (homebrew/core).
# ==> New Formulae
# asuka                      fplll                      openstackclient
# cddlib                     gau                        pfetch
# cdo                        ghz                        qrcp
# clip                       ghz-web                    rbtools
# code-server                gocloc                     reorder-python-imports
# cqlkit                     graphql-cli                rtorrent
# cucumber-ruby              hdf5-mpi                   semgrep
# dgraph                     kde-extra-cmake-modules    sollya
# dmagnetic                  lanraragi                  spotify-tui
# duckdb                     lc0                        spotifyd
# erlang@22                  leakcanary-shark           trailscraper
# eva                        libolm                     unum
# field3d                    libpqxx@6                  wasm-pack
# flamegraph                 libtorrent-rakshasa        xxh
# flarectl                   lizard-analyzer            zenith
# ==> Updated Formulae
# glib ✔                                   libpqxx
# harfbuzz ✔                               libproxy
# netpbm ✔                                 libpulsar
# abcmidi                                  libqalculate
# abook                                    librdkafka
# adplug                                   libressl
# aliyun-cli                               librsync
# amazon-ecs-cli                           libspectre
# ammonite-repl                            libspiro
# amqp-cpp                                 libtensorflow@1
# angular-cli                              libtorch
# anime-downloader                         libuv
# ansible                                  libwebsockets
# ansible@2.8                              liquibase
# ant                                      lmod
# ant@1.9                                  logstash
# apache-arrow                             lxc
# apache-arrow-glib                        macvim
# apache-flink                             mame
# apollo-cli                               mapserver
# appium                                   mariadb
# arangodb                                 mariadb-connector-c
# armadillo                                mariadb@10.1
# ask-cli                                  mariadb@10.2
# astrometry-net                           mariadb@10.3
# aws-cdk                                  mas
# aws-sdk-cpp                              math-comp
# awscli                                   mavsdk
# awscli@1                                 maxwell
# azure-cli                                mdcat
# azure-storage-cpp                        mdv
# b3sum                                    memcached
# babl                                     mercury
# balena-cli                               mesa
# ballerina                                meson
# bandwhich                                mftrace
# baobab                                   mg
# basex                                    mgba
# bat                                      micro
# batik                                    micronaut
# bazel                                    mikutter
# bde                                      mill
# benthos                                  minidlna
# bento4                                   minikube
# bind                                     minimal-racket
# bindfs                                   minizip2
# bison                                    mk-configure
# bitrise                                  mkdocs
# bluetoothconnector                       mm-common
# bmake                                    mmctl
# borgmatic                                moarvm
# botan                                    mockolo
# btfs                                     molten-vk
# bundletool                               monero
# bwfmetaedit                              mono
# c-ares                                   monolith
# caf                                      mosh
# caffe                                    movgrab
# calicoctl                                mpd
# capstone                                 mpv
# cargo-completion                         mu
# cartridge-cli                            mutt
# cassandra-cpp-driver                     mvnvm
# catch2                                   mvtools
# ccfits                                   mysql
# cdk8s                                    mysql-search-replace
# cfitsio                                  nano
# cfn-lint                                 nanopb-generator
# cfr-decompiler                           nats-server
# cglm                                     netdata
# cgns                                     netlify-cli
# chadwick                                 nettle
# chakra                                   newman
# chamber                                  newrelic-cli
# cheat                                    nginx
# chezmoi                                  ngspice
# chromaprint                              ngt
# circleci                                 nift
# citus                                    nnn
# clamav                                   node
# claws-mail                               node-build
# clingo                                   node@12
# cloc                                     node_exporter
# clojure-lsp                              nomad
# clojurescript                            now-cli
# closure-compiler                         nqp
# clp                                      nss
# cmake                                    nushell
# codespell                                nuttcp
# cointop                                  nvc
# commandbox                               oauth2_proxy
# conan                                    oha
# concurrencykit                           okteto
# console_bridge                           onscripter
# consul                                   opa
# contentful-cli                           open-babel
# convox                                   opencc
# coq                                      openconnect
# corral                                   opencv
# cosi                                     opencv@2
# couchdb                                  opencv@3
# cpl                                      openexr
# cppcheck                                 openfortivpn
# cpputest                                 openh264
# csvq                                     openimageio
# ctl                                      openssh
# curaengine                               openvdb
# cython                                   operator-sdk
# daq                                      orc-tools
# dartsim                                  osm2pgrouting
# dasht                                    oxipng
# dasm                                     pachi
# datetime-fortran                         paket
# dav1d                                    parallel
# debianutils                              pari
# deno                                     passenger
# detekt                                   pcre2
# devspace                                 pdf2htmlex
# dhall                                    pdfcpu
# dhall-json                               pdfsandwich
# dhall-lsp-server                         pdnsrec
# dhall-yaml                               petsc
# diffoscope                               petsc-complex
# direnv                                   pgpool-ii
# dmd                                      pgrouting
# dnscontrol                               phoronix-test-suite
# dnsdist                                  php
# dnstwist                                 php@7.2
# docfx                                    php@7.3
# docker                                   phpstan
# docker-completion                        phpunit
# dolt                                     pianobar
# dovecot                                  picat
# dub                                      pidgin
# dungeon                                  pike
# duo_unix                                 pipenv
# duplicity                                pipx
# dvc                                      plantuml
# dxpy                                     platformio
# e2fsprogs                                plenv
# earthly                                  pmd
# easy-tag                                 pngpaste
# efl                                      pnpm
# ejabberd                                 poetry
# ejdb                                     polynote
# embree                                   ponyc
# emscripten                               posh
# epic5                                    postgresql
# erlang                                   postgresql@10
# erlang@21                                postgresql@11
# eslint                                   postgresql@9.5
# etcd                                     postgresql@9.6
# ethereum                                 postgrest
# evince                                   pre-commit
# exif                                     procs
# exploitdb                                prometheus
# ext2fuse                                 proteinortho
# fades                                    protobuf
# fargatecli                               protobuf-c
# fastd                                    protoc-gen-go
# fastlane                                 protoc-gen-grpc-web
# fauna-shell                              prototool
# fd                                       proxytunnel
# fdroidserver                             pspg
# fetchmail                                pueue
# ffmpeg                                   pulumi
# ffmpeg2theora                            purescript
# ffmpeg@2.8                               pwntools
# ffmpegthumbnailer                        pycodestyle
# ffms2                                    pylint
# ffsend                                   pyside
# file-roller                              python-markdown
# findent                                  python-yq
# firebase-cli                             qalculate-gtk
# flake8                                   qcli
# flow                                     qemu
# fluent-bit                               qpid-proton
# flyway                                   quazip
# fmt                                      quill
# folly                                    r
# fontforge                                rakudo
# fonttools                                rawtoaces
# fop                                      rbspy
# forcecli                                 rclone
# fossil                                   rdesktop
# freeipmi                                 rdfind
# freerdp                                  rdiff-backup
# freeswitch                               rdup
# freetds                                  redis
# frotz                                    redis@3.2
# frugal                                   redis@4.0
# fuseki                                   redpen
# futhark                                  repo
# game-music-emu                           rex
# gatsby-cli                               ripgrep
# gcab                                     ripgrep-all
# gcviewer                                 rom-tools
# gdal                                     root
# gdb                                      roswell
# gdk-pixbuf                               rrdtool
# gerbil-scheme                            ruby-build
# gexiv2                                   rust
# gh                                       s3fs
# ghex                                     salt
# git                                      sane-backends
# git-absorb                               scrcpy
# git-annex                                sd
# git-cola                                 sentencepiece
# git-lfs                                  serf
# git-plus                                 serverless
# git-quick-stats                          sfk
# gitlab-gem                               shadowenv
# gitlab-runner                            shared-mime-info
# gitleaks                                 shogun
# gleam                                    signal-cli
# glib-networking                          simple-scan
# glooctl                                  singular
# gnome-recipes                            siril
# gnu-chess                                skaffold
# gnu-getopt                               skopeo
# gnumeric                                 sleuthkit
# gnutls                                   snakemake
# go                                       snapraid
# go-bindata                               sngrep
# go-jsonnet                               sonarqube
# go@1.13                                  sonobuoy
# goaccess                                 sourcedocs
# gobject-introspection                    spdlog
# godep                                    sphinx-doc
# goffice                                  spice-protocol
# gom                                      spim
# gomplate                                 spirv-cross
# google-authenticator-libpam              spotbugs
# goose                                    sqlcipher
# gopass                                   sslyze
# goreleaser                               starship
# gr-osmosdr                               step
# gradle                                   stoken
# grafana                                  stone-soup
# graphene                                 stress-ng
# grc                                      subnetcalc
# groovy                                   sundials
# groovysdk                                swagger-codegen
# grpc                                     swagger-codegen@2
# grpc-swift                               swift
# grpcurl                                  swift-protobuf
# gsettings-desktop-schemas                swiftformat
# gsoap                                    synfig
# gspell                                   sysdig
# gst-plugins-bad                          tanka
# gst-plugins-ugly                         tccutil
# gst-validate                             tealdeer
# gtranslator                              telegraf
# gucharmap                                teleport
# gwt                                      template-glib
# handbrake                                tengo
# hapi-fhir-cli                            terraform
# haskell-stack                            terragrunt
# haxe                                     testssl
# healpix                                  texlab
# hebcal                                   tfenv
# helm                                     tflint
# helmfile                                 tile38
# helmsman                                 timidity
# highlight                                tintin
# hiredis                                  tmux-xpanes
# hlint                                    tmuxinator-completion
# homeassistant-cli                        tokei
# homebank                                 tomcat
# hopenpgp-tools                           tomcat@7
# hpack                                    tomcat@8
# htmlcleaner                              tomee-plume
# hugo                                     tomee-plus
# hyperfine                                tomee-webprofile
# hyperscan                                topgrade
# i2p                                      tor
# i2pd                                     tox
# iam-policy-json-to-terraform             translate-shell
# idris                                    transmission-cli
# ilmbase                                  travis
# imagemagick                              treefrog
# imagemagick@6                            tth
# imgproxy                                 tundra
# inlets                                   twarc
# ipfs                                     typescript
# iso-codes                                ucloud
# istioctl                                 unbound
# janet                                    uncrustify
# jansson                                  ungit
# jc                                       unpaper
# jdupes                                   urdfdom
# jena                                     urdfdom_headers
# jenkins                                  urh
# jenv                                     util-linux
# jetty                                    uwsgi
# jetty-runner                             v8
# jfrog-cli-go                             vagrant-completion
# jhipster                                 vala
# jmeter                                   vale
# joplin                                   vamp-plugin-sdk
# jrnl                                     vapoursynth
# jsonnet                                  vapoursynth-imwri
# jsonrpc-glib                             vapoursynth-ocr
# jsvc                                     vapoursynth-sub
# jupyterlab                               vault
# just                                     vcs
# kakoune                                  velero
# katago                                   vert.x
# kitchen-sync                             vfuse
# knot                                     vim
# komposition                              vips
# krb5                                     volta
# kubeaudit                                vpn-slice
# kubernetes-cli                           vulkan-headers
# kubernetes-service-catalog-client        wandio
# kubeseal                                 wartremover
# kumactl                                  wcslib
# kumo                                     weaver
# kustomize                                webtorrent-cli
# kyma-cli                                 weechat
# lazygit                                  when
# lcm                                      whistle
# ledger                                   wildfly-as
# lego                                     wimlib
# lensfun                                  wireguard-tools
# lerna                                    wireshark
# libarchive                               wrangler
# libav                                    wtf
# libbladerf                               wtfutil
# libcpuid                                 wxmac
# libdazzle                                x264
# libdeflate                               xa
# libepoxy                                 xgboost
# libexif                                  xmrig
# libfabric                                xrootd
# libfido2                                 yaegi
# libfreenect                              yaws
# libgweather                              youtube-dl
# libhttpserver                            z3
# libksba                                  zabbix
# libmypaint                               zbackup
# libngspice                               zeek
# libnice                                  zero-install
# libphonenumber                           zola
# libplctag                                zookeeper
# libpq                                    zstd
# ==> Deleted Formulae
# crc                        gnome-builder              pijul
#
# ==> Downloading https://homebrew.bintray.com/bottles/libomp-10.0.0.catalina.bott
# ==> Downloading from https://akamai.bintray.com/0e/0ea757dbea7bf12141ef1d209d2f3
# ######################################################################## 100.0%
# ==> Pouring libomp-10.0.0.catalina.bottle.tar.gz
# 🍺  /usr/local/Cellar/libomp/10.0.0: 9 files, 1.3MB

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
y=df_clean['fraud']
X=df_clean.drop('fraud',axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

'''
Documentation for xgboost:

https://xgboost.readthedocs.io/en/latest/
'''
model = XGBClassifier()

# fit the model with the training data
model.fit(X_train,y_train)

y_predict_test = model.predict(X_test)
#print('\nTarget on test data',predict_test) 

# Accuracy Score on test dataset
accuracy_test = accuracy_score(y_test,y_predict_test)
print('XGboost classifier results:')
print('\naccuracy_score : ', accuracy_test)

print(f'precision: {precision_score(y_test,y_predict_test)}')
print(f'recall: {recall_score(y_test,y_predict_test)}')
# Out:
# XGboost classifier results:
#
# accuracy_score :  0.9743375174337517
# precision: 0.8239202657807309
# recall: 0.8641114982578397
